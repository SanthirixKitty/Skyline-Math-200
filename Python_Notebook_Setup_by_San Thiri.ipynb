# %% [markdown]
# <a href="https://colab.research.google.com/github/SanthirixKitty/Skyline-Math-200/blob/main/Python_Notebook_Setup_by_San%20Thiri.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Research question 2:Is there an association between feeling nauseous in the last two weeks and the number of siblings you have?

# %% [markdown]
# Codebook Variable #3

# %% [markdown]
#   ![Screen Shot 2023-04-30 at 1.16.25 PM.png](data:image/png;base64,...)

# %%
df['H4ID10D'].value_counts()
# Out:
# 0    4678
#      1390
# 1     436
# Name: H4ID10D, dtype: int64

# %%
df['Nausea_2weeks']=df['H4ID10D']

# %%
df['Nausea_2weeks'] = df['Nausea_2weeks'].loc[ df['Nausea_2weeks'] !=' ']
df['Nausea_2weeks'].value_counts()
# Out:
# 0    4678
# 1     436
# Name: Nausea_2weeks, dtype: int64

# %%
df['Nausea_2weeks'].replace(['0','1'] , ['No','Yes' ], inplace = True)
df['Nausea_2weeks'].value_counts()
# Out:
# No     4678
# Yes     436
# Name: Nausea_2weeks, dtype: int64

# %%
pip install researchpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import researchpy as rp

# %%
rp.summary_cat(df['Nausea_2weeks'])
# Out:
#         Variable Outcome  Count  Percent
# 0  Nausea_2weeks      No   4678    91.47
# 1                    Yes    436     8.53

# %%
df['Nausea_2weeks'].value_counts().plot(kind ='pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='Nausea_2weeks'>

# %%
plt.ylabel("Percent")
df['Nausea_2weeks'].value_counts(normalize = True).plot(kind ='bar', color = 'red', width = 0.2, alpha = 0.1, grid = True)
# Out:
# <Axes: ylabel='Percent'>

# %% [markdown]
# Codebook Variable #4

# %% [markdown]
# ![Screen Shot 2023-04-30 at 1.16.55 PM.png](data:image/png;base64,...)

# %%
#Check the data type for H4GH6
df['H4WS1'].dtype
# Out:
# dtype('O')

# %%
df['Number_of_siblings'] = df['H4WS1']
df['Number_of_siblings'].dtype
# Out:
# dtype('O')

# %%
df['Number_of_siblings'] = pd.to_numeric( df['Number_of_siblings'] , errors= 'coerce')
df['Number_of_siblings'].dtype
# Out:
# dtype('float64')

# %%
df['Number_of_siblings'] = df['Number_of_siblings'].loc[ df['Number_of_siblings'] !=' ' ]
df['Number_of_siblings'] = df['Number_of_siblings'].loc[ df['Number_of_siblings'] !='96' ]
df['Number_of_siblings'] = df['Number_of_siblings'].loc[ df['Number_of_siblings'] !='98' ]
df['Number_of_siblings'] = df['Number_of_siblings'].loc[ df['Number_of_siblings'] < 20 ]
df['Number_of_siblings'].max()
# Out:
# 19.0

# %%
df['Number_of_siblings'].mean()
# Out:
# 2.852993130520118

# %%
pip install researchpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import researchpy as rp

# %%
rp.summary_cont(df['Number_of_siblings'])
# Out:
#              Variable       N   Mean      SD      SE  95% Conf.  Interval
# 0  Number_of_siblings  5095.0  2.853  2.2702  0.0318     2.7906    2.9153

# %%
rp.summarize(df['Number_of_siblings'])
# Out:
#                  Name     N   Mean Median Variance      SD      SE  \
# 0  Number_of_siblings  5095  2.853    2.0   5.1537  2.2702  0.0318
#
#   95% Conf. Interval
# 0   [2.7906, 2.9153]

# %%
df['Number_of_siblings'].describe()
# Out:
# count    5095.000000
# mean        2.852993
# std         2.270174
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%         4.000000
# max        19.000000
# Name: Number_of_siblings, dtype: float64

# %%
import seaborn as sns

# %%
#Create a histogram with normal curve [kde =True]
sns.histplot( x = 'Number_of_siblings', data = df, kde =True , bins = 20)
# Out:
# <Axes: xlabel='Number_of_siblings', ylabel='Count'>

# %%
sns.boxplot( x = 'Number_of_siblings', data = df)
# Out:
# <Axes: xlabel='Number_of_siblings'>
